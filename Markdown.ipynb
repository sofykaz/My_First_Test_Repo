# %% [markdown]
# <a href="https://colab.research.google.com/github/sofykaz/My_First_Test_Repo/blob/main/Markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown
#
# 1. Список
#   1.   Даша
#   2.   Соня
# 3. Рисунок
#
#
# ![image.png](data:image/png;base64,...)
# 3. Таблица
#
# 4. Ссылка
# [Яндекс Ссылка](https://lifehacker.ru/chto-takoe-markdown/)
